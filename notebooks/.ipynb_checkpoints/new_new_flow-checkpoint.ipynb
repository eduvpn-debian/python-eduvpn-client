# %%
from typing import Dict, Union
import sys
import os 
from pathlib import Path
import requests
import socket
import pandas as pd
import webbrowser
from requests_oauthlib import OAuth2Session
import gi
import tempfile
gi.require_version('NM', '1.0')
from gi.repository import GLib, NM

# %%
sys.path.append(str(Path().absolute().parent))

# %%
from eduvpn.oauth2 import one_request, get_open_port
from eduvpn.crypto import gen_code_challenge, gen_code_verifier, common_name_from_cert

# %% [markdown]
# # Settings

# %%
# client settings
DISCO_URI = 'https://disco.eduvpn.org/'
ORGANISATION_URI = DISCO_URI + "organization_list.json"
SERVER_URI = DISCO_URI + "server_list.json"
client_id = "org.eduvpn.app.linux"
scope = ["config"]
code_challenge_method = "S256"

# %%
# our configuration
organisation = 'SURFnet bv'
server = 'Demo'
institute = 'Demo'
LANGUAGE = 'nl'
COUNTRY = "nl-NL"

# %% [markdown]
# # Utils

# %%
def extract_translation(d: Union[str, Dict[str, str]]):
    if type(d) != dict:
        return d
    for m in [COUNTRY, LANGUAGE, 'en-US', 'en']:
        try:
            return d[m]
        except KeyError:
            continue
    return list(d.values())[0]  # otherwise just return first in list

# %% [markdown]
# # institute access list

# %%
servers_response = requests.get(SERVER_URI)
servers_response.json()['server_list']
# Out:
# {'v': '2020-05-25T18:15:55+00:00',
#  'server_list': [{'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.rash.al/',
#    'display_name': {'en-US': 'Albania', 'sq-AL': 'Shqiperi'},
#    'public_key_list': ['Xv3l24gbMX8NtTnFQbWO2fGKPwKuc6EbjQDv8qw2GVk'],
#    'support_contact': ['mailto:helpdesk@rash.al']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://gdpt-eduvpndev1.tnd.aarnet.edu.au/',
#    'display_name': {'da-DK': 'Australien',
#     'en-US': 'Australia',
#     'nb-NO': 'Australia',
#     'nl-NL': 'Australië'},
#    'public_key_list': ['HpY5RKF0OzYcYUcogKzgt1MvC6CxBmDJoUBsyiKjioA']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.deic.dk/',
#    'display_name': {'da-DK': 'Danmark',
#     'en-US': 'Denmark',
#     'nb-NO': 'Danmark',
#     'nl-NL': 'Denemarken'},
#    'public_key_list': ['bRTz33KIuYo_w_-AbzNtdmLDqIm11_eGiHXQniojxY4'],
#    'support_contact': ['mailto:eduvpn@deic.dk']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.eenet.ee/',
#    'display_name': {'et-EE': 'Eesti', 'en-US': 'Estonia'},
#    'public_key_list': ['jGpivOdwCRoLlexYKQjulZPPP4s3d9SVBFslI6RroAo'],
#    'support_contact': ['mailto:eduvpn@eenet.ee']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn1.funet.fi/',
#    'display_name': {'en-US': 'Finland',
#     'nb-NO': 'Finland',
#     'nl-NL': 'Finland'},
#    'public_key_list': ['H4NTnM18BJgU_B3r8OBDVblBSfozB2Zu97I_ag2whmM'],
#    'support_contact': ['mailto:eduvpn@csc.fi']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn-poc.renater.fr/',
#    'display_name': {'en-US': 'France',
#     'nb-NO': 'Frankrike',
#     'nl-NL': 'Frankrijk'},
#    'public_key_list': ['ePVNzE15h0yS6Xf3s8nJWmc8V6FeFziA3TZr0uOacFg'],
#    'support_contact': ['https://assistance.renater.fr/']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn1.eduvpn.de/',
#    'display_name': {'de-DE': 'Deutschland',
#     'en-US': 'Germany',
#     'nb-NO': 'Tyskland',
#     'nl-NL': 'Duitsland'},
#    'public_key_list': ['QjJHMit3vhHwLKi-fu2dXXSxMxnkskFVS3hMwyCnWQs'],
#    'support_contact': ['mailto:eduvpn@dfn.de', 'tel:+49308842999120']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.marwan.ma/',
#    'display_name': {'en-US': 'Morocco',
#     'nb-NO': 'Marokko',
#     'nl-NL': 'Marokko'},
#    'public_key_list': ['aX-El_yRPdcUDF5S2smQ-9U7BzB35_1RtFYSjbHfEz8'],
#    'support_contact': ['mailto:eduvpn-support@marwan.ma',
#     'tel:+212700062200']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://guest.eduvpn.no/',
#    'display_name': {'da-DK': 'Norge',
#     'en-US': 'Norway',
#     'nb-NO': 'Norge',
#     'nl-NL': 'Noorwegen'},
#    'public_key_list': ['qOLCcqXWZm9nmjsrwiJQxxWD606vDEJ2MIcc85oJmnE'],
#    'support_contact': ['mailto:kontakt@uninett.no']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://vpn.pern.edu.pk/',
#    'display_name': {'en-US': 'Pakistan',
#     'nb-NO': 'Pakistan',
#     'nl-NL': 'Pakistan'},
#    'public_key_list': ['LKWFZblpTFvFDY4E_0tnD8yHpK-iOSrJop_1x-A4cQ8'],
#    'support_contact': ['mailto:eduvpn@pern.edu.pk']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.ac.lk/',
#    'display_name': {'en-US': 'Sri Lanka',
#     'nb-NO': 'Sri Lanka',
#     'nl-NL': 'Sri Lanka'},
#    'public_key_list': ['drq4-3Sg35UJHxVfx-ssR3onjHihCVH-zjXYPnEfudI'],
#    'support_contact': ['mailto:eduvpn@learn.ac.lk']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://nl.eduvpn.org/',
#    'display_name': {'da-DK': 'Holland',
#     'en-US': 'The Netherlands',
#     'nb-NO': 'Nederland',
#     'nl-NL': 'Nederland'},
#    'public_key_list': ['O53DTgB956magGaWpVCKtdKIMYqywS3FMAC5fHXdFNg'],
#    'support_contact': ['mailto:eduvpn@surfnet.nl']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.renu.ac.ug/',
#    'display_name': {'en-US': 'Uganda', 'nb-NO': 'Uganda', 'nl-NL': 'Oeganda'},
#    'public_key_list': ['4plEYRW26amB1-PcRRxWcKlEcDXsUO4yNHnf0VA2MPE'],
#    'support_contact': ['mailto:technical@renu.ac.ug', 'tel:+256783979515']},
#   {'server_type': 'secure_internet',
#    'base_url': 'https://eduvpn.uran.ua/',
#    'display_name': {'en-US': 'Ukraine',
#     'nb-NO': 'Ukraina',
#     'nl-NL': 'Oekraïne',
#     'uk-UA': 'Україна'},
#    'public_key_list': ['gCUDsmSIn0pVPc4C-QNLsBil6WxkwDDwxfvTC262p9U'],
#    'support_contact': ['mailto:dopomoga@uran.ua', 'tel:+380442049816']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://sunset.nuonet.fr/',
#    'display_name': 'CNOUS',
#    'support_contact': ['mailto:support-technique-nuo@listes.nuonet.fr']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn-csc.funet.fi/',
#    'display_name': 'CSC - IT Center for Science Ltd.',
#    'support_contact': ['mailto:eduvpn@csc.fi']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://demo.eduvpn.nl/',
#    'display_name': 'Demo',
#    'support_contact': ['mailto:eduvpn@surfnet.nl']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://access.diak.fi/',
#    'display_name': 'DIAK',
#    'support_contact': ['mailto:tuki@diak.fi', 'tel:+358294696070']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://differ.eduvpn.nl/',
#    'display_name': 'DIFFER'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://egi.eduvpn.nl/',
#    'display_name': 'EGI Foundation'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.ensma.fr/',
#    'display_name': 'Ensma',
#    'support_contact': ['mailto:dsi@ensma.fr']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eur.eduvpn.nl/',
#    'display_name': 'Erasmus University Rotterdam'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://prod-eduvpn01.geant.org/',
#    'display_name': 'GÉANT',
#    'support_contact': ['mailto:it@geant.org']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.heanet.ie/',
#    'display_name': 'HEAnet'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.hs-osnabrueck.de/',
#    'display_name': 'Hochschule Osnabrück',
#    'support_contact': ['https://www.hs-osnabrueck.de/servicedesk/',
#     'tel:+495419697100',
#     'mailto:servicedesk@hs-osnabrueck.de']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.ipb.pt/',
#    'display_name': 'Instituto Politécnico de Bragança',
#    'support_contact': ['mailto:ccom@ipb.pt',
#     'http://www.ipb.pt/si',
#     'tel:+351273303050']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://esciencecenter.eduvpn.nl/',
#    'display_name': 'Netherlands eScienceCenter'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://nikhef.eduvpn.nl/',
#    'display_name': 'Nikhef'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.hec.gov.pk/',
#    'display_name': 'Pakistan Education & Research Network',
#    'support_contact': ['mailto:eduvpn@pern.edu.pk']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.perdanauniversity.edu.my/',
#    'display_name': 'Perdana University',
#    'support_contact': ['mailto:it-helpdesk@perdanauniversity.edu.my']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.pionier.net.pl/',
#    'display_name': 'PIONIER',
#    'support_contact': ['mailto:contact@eduvpn.pionier.net.pl']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.polsl.pl/',
#    'display_name': 'Politechnika Śląska'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://ru.eduvpn.nl/',
#    'display_name': {'en-US': 'Radboud University',
#     'nl-NL': 'Radboud Universiteit'}},
#   {'server_type': 'institute_access',
#    'base_url': 'https://leduvpn.renu.ac.ug/',
#    'display_name': 'RENU',
#    'support_contact': ['tel:+256783979515', 'mailto:technical@renu.ac.ug']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://stc.eduvpn.nl/',
#    'display_name': 'STC Group'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://surfnet.eduvpn.nl/',
#    'display_name': 'SURFnet'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.tuni.fi/',
#    'display_name': 'Tampere Universities',
#    'support_contact': ['mailto:it-helpdesk@tuni.fi',
#     'https://www.tuni.fi/it-palvelut']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.hochschule-trier.de/',
#    'display_name': {'en': 'Trier University of Applied Sciences',
#     'de': 'Hochschule Trier'},
#    'support_contact': ['https://www.hochschule-trier.de/rzht/it-support',
#     'tel:+496518103555',
#     'mailto:eduvpn@help.hochschule-trier.de']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://trimbos.eduvpn.nl/',
#    'display_name': 'Trimbos-instituut'},
#   {'server_type': 'institute_access',
#    'base_url': 'https://uninett.eduvpn.no/',
#    'display_name': 'Uninett',
#    'support_contact': ['mailto:kontakt@uninett.no']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.unit.no/',
#    'display_name': 'Unit',
#    'support_contact': ['mailto:kontakt@uninett.no']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.uminho.pt/',
#    'display_name': {'en-US': 'University of Minho',
#     'pt-PT': 'Universidade do Minho'},
#    'support_contact': ['mailto:servicedesk@scom.uminho.pt',
#     'tel:+351253601000']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.unimes.fr/',
#    'display_name': {'en': 'University of Nimes', 'fr': 'Université de Nimes'},
#    'support_contact': ['mailto:eduvpn@unimes.fr']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.uni-osnabrueck.de/',
#    'display_name': {'en-US': 'University of Osnabrück',
#     'de-DE': 'Universität Osnabrück'},
#    'support_contact': ['https://www.rz.uni-osnabrueck.de/dienste/beratung/beratungsteam/index.html',
#     'tel:+495419693333',
#     'mailto:Beratung@rz.uni-osnabrueck.de']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://ut.eduvpn.nl/',
#    'display_name': {'en-US': 'University of Twente',
#     'nl-NL': 'Universiteit Twente'}},
#   {'server_type': 'institute_access',
#    'base_url': 'https://hku.eduvpn.nl/',
#    'display_name': {'en-US': 'Utrecht School of the Arts',
#     'nl-NL': 'Hogeschool voor de Kunsten Utrecht'}},
#   {'server_type': 'institute_access',
#    'base_url': 'https://eduvpn.vamk.fi/',
#    'display_name': 'VAMK - University of Applied Sciences',
#    'support_contact': ['mailto:helpdesk@vamk.fi']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://vu.eduvpn.nl/',
#    'display_name': 'Vrije Universiteit',
#    'support_contact': ['mailto:servicedesk.it@vu.nl', 'tel:+31205980000']},
#   {'server_type': 'institute_access',
#    'base_url': 'https://hiof.eduvpn.no/',
#    'display_name': {'en': 'Østfold University College',
#     'nb': 'Høgskolen i Østfold'},
#    'support_contact': ['mailto:kontakt@uninett.no']}]}

# %%
institute_access_response = requests.get(institute_access_uri)
institute_access_list = pd.DataFrame(institute_access_response.json()['instances'])
institute_access_list['display_name'] = institute_access_list['display_name'].apply(extract_translation)
institute_access_list
# Out:
#                                     base_uri  \
# 0                  https://sunset.nuonet.fr/
# 1               https://eduvpn-csc.funet.fi/
# 2                    https://demo.eduvpn.nl/
# 3                    https://access.diak.fi/
# 4                  https://differ.eduvpn.nl/
# 5                     https://egi.eduvpn.nl/
# 6                   https://eduvpn.ensma.fr/
# 7                     https://eur.eduvpn.nl/
# 8           https://prod-eduvpn01.geant.org/
# 9                  https://eduvpn.heanet.ie/
# 10          https://eduvpn.hs-osnabrueck.de/
# 11                    https://eduvpn.ipb.pt/
# 12         https://esciencecenter.eduvpn.nl/
# 13                 https://nikhef.eduvpn.nl/
# 14                https://eduvpn.hec.gov.pk/
# 15  https://eduvpn.perdanauniversity.edu.my/
# 16            https://eduvpn.pionier.net.pl/
# 17                  https://eduvpn.polsl.pl/
# 18                     https://ru.eduvpn.nl/
# 19               https://leduvpn.renu.ac.ug/
# 20                    https://stc.eduvpn.nl/
# 21                https://surfnet.eduvpn.nl/
# 22                   https://eduvpn.tuni.fi/
# 23       https://eduvpn.hochschule-trier.de/
# 24                https://trimbos.eduvpn.nl/
# 25                https://uninett.eduvpn.no/
# 26                   https://eduvpn.unit.no/
# 27                 https://eduvpn.uminho.pt/
# 28                 https://eduvpn.unimes.fr/
# 29         https://eduvpn.uni-osnabrueck.de/
# 30                     https://ut.eduvpn.nl/
# 31                    https://hku.eduvpn.nl/
# 32                   https://eduvpn.vamk.fi/
# 33                     https://vu.eduvpn.nl/
# 34                   https://hiof.eduvpn.no/
#
#                              display_name  \
# 0                                   CNOUS
# 1        CSC - IT Center for Science Ltd.
# 2                                    Demo
# 3                                    DIAK
# 4                                  DIFFER
# 5                          EGI Foundation
# 6                                   Ensma
# 7            Erasmus University Rotterdam
# 8                                   GÉANT
# 9                                  HEAnet
# 10                   Hochschule Osnabrück
# 11      Instituto Politécnico de Bragança
# 12             Netherlands eScienceCenter
# 13                                 Nikhef
# 14  Pakistan Education & Research Network
# 15                     Perdana University
# 16                                PIONIER
# 17                    Politechnika Śląska
# 18                   Radboud Universiteit
# 19                                   RENU
# 20                              STC Group
# 21                                SURFnet
# 22                   Tampere Universities
# 23   Trier University of Applied Sciences
# 24                      Trimbos-instituut
# 25                                Uninett
# 26                                   Unit
# 27                    University of Minho
# 28                    University of Nimes
# 29                University of Osnabrück
# 30                    Universiteit Twente
# 31     Hogeschool voor de Kunsten Utrecht
# 32  VAMK - University of Applied Sciences
# 33                     Vrije Universiteit
# 34             Østfold University College
#
#                                                 logo  \
# 0       https://static.eduvpn.nl/disco/img/crous.png
# 1         https://static.eduvpn.nl/disco/img/csc.png
# 2        https://static.eduvpn.nl/disco/img/demo.png
# 3        https://static.eduvpn.nl/disco/img/diak.png
# 4      https://static.eduvpn.nl/disco/img/differ.png
# 5         https://static.eduvpn.nl/disco/img/egi.png
# 6       https://static.eduvpn.nl/disco/img/ensma.png
# 7         https://static.eduvpn.nl/disco/img/eur.png
# 8       https://static.eduvpn.nl/disco/img/geant.png
# 9      https://static.eduvpn.nl/disco/img/heanet.png
# 10      https://static.eduvpn.nl/disco/img/hs-os.png
# 11        https://static.eduvpn.nl/disco/img/ipb.png
# 12      https://static.eduvpn.nl/disco/img/nlesc.png
# 13     https://static.eduvpn.nl/disco/img/nikhef.png
# 14       https://static.eduvpn.nl/disco/img/pern.png
# 15    https://static.eduvpn.nl/disco/img/perdana.png
# 16    https://static.eduvpn.nl/disco/img/pionier.png
# 17      https://static.eduvpn.nl/disco/img/polsl.png
# 18         https://static.eduvpn.nl/disco/img/ru.png
# 19       https://static.eduvpn.nl/disco/img/renu.png
# 20  https://static.eduvpn.nl/disco/img/stc-group.png
# 21    https://static.eduvpn.nl/disco/img/surfnet.png
# 22       https://static.eduvpn.nl/disco/img/tuni.png
# 23    https://static.eduvpn.nl/disco/img/hstrier.png
# 24    https://static.eduvpn.nl/disco/img/trimbos.png
# 25    https://static.eduvpn.nl/disco/img/uninett.png
# 26       https://static.eduvpn.nl/disco/img/unit.png
# 27     https://static.eduvpn.nl/disco/img/uminho.png
# 28     https://static.eduvpn.nl/disco/img/unimes.png
# 29     https://static.eduvpn.nl/disco/img/uni-os.png
# 30    https://static.eduvpn.nl/disco/img/utwente.png
# 31        https://static.eduvpn.nl/disco/img/hku.png
# 32       https://static.eduvpn.nl/disco/img/vamk.png
# 33         https://static.eduvpn.nl/disco/img/vu.png
# 34       https://static.eduvpn.nl/disco/img/hiof.png
#
#                                       support_contact
# 0     [mailto:support-technique-nuo@listes.nuonet.fr]
# 1                              [mailto:eduvpn@csc.fi]
# 2                          [mailto:eduvpn@surfnet.nl]
# 3            [mailto:tuki@diak.fi, tel:+358294696070]
# 4                                                 NaN
# 5                                                 NaN
# 6                               [mailto:dsi@ensma.fr]
# 7                                                 NaN
# 8                               [mailto:it@geant.org]
# 9                                                 NaN
# 10  [https://www.hs-osnabrueck.de/servicedesk/, te...
# 11  [mailto:ccom@ipb.pt, http://www.ipb.pt/si, tel...
# 12                                                NaN
# 13                                                NaN
# 14                        [mailto:eduvpn@pern.edu.pk]
# 15      [mailto:it-helpdesk@perdanauniversity.edu.my]
# 16             [mailto:contact@eduvpn.pionier.net.pl]
# 17                                                NaN
# 18                                                NaN
# 19   [tel:+256783979515, mailto:technical@renu.ac.ug]
# 20                                                NaN
# 21                                                NaN
# 22  [mailto:it-helpdesk@tuni.fi, https://www.tuni....
# 23  [https://www.hochschule-trier.de/rzht/it-suppo...
# 24                                                NaN
# 25                        [mailto:kontakt@uninett.no]
# 26                        [mailto:kontakt@uninett.no]
# 27  [mailto:servicedesk@scom.uminho.pt, tel:+35125...
# 28                          [mailto:eduvpn@unimes.fr]
# 29  [https://www.rz.uni-osnabrueck.de/dienste/bera...
# 30                                                NaN
# 31                                                NaN
# 32                          [mailto:helpdesk@vamk.fi]
# 33    [mailto:servicedesk.it@vu.nl, tel:+31205980000]
# 34                        [mailto:kontakt@uninett.no]

# %% [markdown]
# # organisation list

# %%
organisation_response = requests.get(organisation_url)
organisation_response.json()
#organization_list = pd.DataFrame(organisation_response.json()['organization_list'])
#organization_list['display_name'] = organization_list['display_name'].apply(extract_translation)
#organization_list['keyword_list'] = organization_list['keyword_list'].apply(extract_translation)
#organization_list
# Out:
# JSONDecodeErrorTraceback (most recent call last)
# <ipython-input-9-6c88e811605d> in <module>
#       1 organisation_response = requests.get(organisation_url)
# ----> 2 organisation_response.json()
#       3 #organization_list = pd.DataFrame(organisation_response.json()['organization_list'])
#       4 #organization_list['display_name'] = organization_list['display_name'].apply(extract_translation)
#       5 #organization_list['keyword_list'] = organization_list['keyword_list'].apply(extract_translation)
#
# ~/Work/python-eduvpn-client/venv/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# /usr/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /usr/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # Secure internet

# %%
secure_internet_response = requests.get(secure_internet_uri)
#secure_internet_response.json()['instances']
secure_internet_list = pd.DataFrame(secure_internet_response.json()['instances'])
secure_internet_list['display_name'] = secure_internet_list['display_name'].apply(extract_translation)
secure_internet_list
# Out:
#                                       base_uri display_name  \
# 0                      https://eduvpn.rash.al/      Albania
# 1   https://gdpt-eduvpndev1.tnd.aarnet.edu.au/    Australië
# 2                      https://eduvpn.deic.dk/   Denemarken
# 3                     https://eduvpn.eenet.ee/      Estonia
# 4                    https://eduvpn1.funet.fi/      Finland
# 5               https://eduvpn-poc.renater.fr/    Frankrijk
# 6                   https://eduvpn1.eduvpn.de/    Duitsland
# 7                    https://eduvpn.marwan.ma/      Marokko
# 8                     https://guest.eduvpn.no/    Noorwegen
# 9                     https://vpn.pern.edu.pk/     Pakistan
# 10                       https://eduvpn.ac.lk/    Sri Lanka
# 11                      https://nl.eduvpn.org/    Nederland
# 12                  https://eduvpn.renu.ac.ug/      Oeganda
# 13                     https://eduvpn.uran.ua/     Oekraïne
#
#                                          logo  \
# 0   https://static.eduvpn.nl/disco/img/al.png
# 1   https://static.eduvpn.nl/disco/img/au.png
# 2   https://static.eduvpn.nl/disco/img/dk.png
# 3   https://static.eduvpn.nl/disco/img/ee.png
# 4   https://static.eduvpn.nl/disco/img/fi.png
# 5   https://static.eduvpn.nl/disco/img/fr.png
# 6   https://static.eduvpn.nl/disco/img/de.png
# 7   https://static.eduvpn.nl/disco/img/ma.png
# 8   https://static.eduvpn.nl/disco/img/no.png
# 9   https://static.eduvpn.nl/disco/img/pk.png
# 10  https://static.eduvpn.nl/disco/img/lk.png
# 11  https://static.eduvpn.nl/disco/img/nl.png
# 12  https://static.eduvpn.nl/disco/img/ug.png
# 13  https://static.eduvpn.nl/disco/img/ua.png
#
#                                   public_key_list  \
# 0   [Xv3l24gbMX8NtTnFQbWO2fGKPwKuc6EbjQDv8qw2GVk]
# 1   [HpY5RKF0OzYcYUcogKzgt1MvC6CxBmDJoUBsyiKjioA]
# 2   [bRTz33KIuYo_w_-AbzNtdmLDqIm11_eGiHXQniojxY4]
# 3   [jGpivOdwCRoLlexYKQjulZPPP4s3d9SVBFslI6RroAo]
# 4   [H4NTnM18BJgU_B3r8OBDVblBSfozB2Zu97I_ag2whmM]
# 5   [ePVNzE15h0yS6Xf3s8nJWmc8V6FeFziA3TZr0uOacFg]
# 6   [QjJHMit3vhHwLKi-fu2dXXSxMxnkskFVS3hMwyCnWQs]
# 7   [aX-El_yRPdcUDF5S2smQ-9U7BzB35_1RtFYSjbHfEz8]
# 8   [qOLCcqXWZm9nmjsrwiJQxxWD606vDEJ2MIcc85oJmnE]
# 9   [LKWFZblpTFvFDY4E_0tnD8yHpK-iOSrJop_1x-A4cQ8]
# 10  [drq4-3Sg35UJHxVfx-ssR3onjHihCVH-zjXYPnEfudI]
# 11  [O53DTgB956magGaWpVCKtdKIMYqywS3FMAC5fHXdFNg]
# 12  [4plEYRW26amB1-PcRRxWcKlEcDXsUO4yNHnf0VA2MPE]
# 13  [gCUDsmSIn0pVPc4C-QNLsBil6WxkwDDwxfvTC262p9U]
#
#                                       support_contact
# 0                           [mailto:helpdesk@rash.al]
# 1                                                 NaN
# 2                             [mailto:eduvpn@deic.dk]
# 3                            [mailto:eduvpn@eenet.ee]
# 4                              [mailto:eduvpn@csc.fi]
# 5                    [https://assistance.renater.fr/]
# 6         [mailto:eduvpn@dfn.de, tel:+49308842999120]
# 7   [mailto:eduvpn-support@marwan.ma, tel:+2127000...
# 8                         [mailto:kontakt@uninett.no]
# 9                         [mailto:eduvpn@pern.edu.pk]
# 10                        [mailto:eduvpn@learn.ac.lk]
# 11                         [mailto:eduvpn@surfnet.nl]
# 12   [mailto:technical@renu.ac.ug, tel:+256783979515]
# 13       [mailto:dopomoga@uran.ua, tel:+380442049816]

# %% [markdown]
# # make selection

# %%
institute_info = institute_access_list[institute_access_list['display_name'] == institute]
institute_info
# Out:
#                   base_uri display_name  \
# 2  https://demo.eduvpn.nl/         Demo
#
#                                           logo             support_contact
# 2  https://static.eduvpn.nl/disco/img/demo.png  [mailto:eduvpn@surfnet.nl]

# %% [markdown]
# ## or in case you select an organisation

# %%
organisation_info = organization_list[organization_list['display_name'] == organisation]
organisation_info
# Out:
#     display_name                  org_id    secure_internet_home  \
# 561   SURFnet bv  https://idp.surfnet.nl  https://nl.eduvpn.org/
#
#                           keyword_list
# 561  SURFnet bv SURF konijn powered by

# %%
info_base_url = institute_info['base_uri'].iloc[0]

# %%
info_url = info_base_url + 'info.json'
info = requests.get(info_url).json()['api']['http://eduvpn.org/api#2']

# %%
api_base_uri = info['api_base_uri']
token_endpoint = info['token_endpoint']
authorization_endpoint = info['authorization_endpoint']

# %%
port = get_open_port()
redirect_uri = f'http://127.0.0.1:{port}/callback'

# %%
oauth = OAuth2Session(client_id, redirect_uri=redirect_uri, auto_refresh_url=token_endpoint, scope=scope)

# %%
code_verifier = gen_code_verifier()
code_challenge = gen_code_challenge(code_verifier)
authorization_url, state = oauth.authorization_url(url=authorization_endpoint,
                                                   code_challenge_method=code_challenge_method,
                                                   code_challenge=code_challenge)

# %%
webbrowser.open(authorization_url)
# Out:
# True

# %%
response = one_request(port, lets_connect=False)
# Out:
# 127.0.0.1 - - [04/May/2020 12:07:02] "GET /callback?code=eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCIsImtpZCI6IldMQTA5RWVfWHdoU0ZYalBOZ2ExT3lXRW40a1pUZ2xNR3ppR1RtRnM5MEEifQ.....8Mm3-GXbVhkbGoHrfaI2pSN3Xaux-M-5Z3lnorxv_JOQLl-KsAApTHY7S9rkzQqjdBznyZNRQII3wSo1UmJKDQ&state=5Wd5AYqOHagqeX27IKTgMbkNRdS9Vx HTTP/1.1" 200 -

# %%
code = response['code'][0]

# %%
assert(state == response['state'][0])

# %%
token = oauth.fetch_token(token_url=token_endpoint,
                          code=code,
                          code_verifier=code_verifier,
                          client_id=oauth.client_id,
                          include_client_id=True,
                          )

# %% [markdown]
# # profile list

# %%
profile_list_response = oauth.get(api_base_uri + '/profile_list')

# %%
profile_list_response.json()['profile_list']['data']
# Out:
# [{'profile_id': 'internet', 'display_name': 'internet', 'two_factor': False},
#  {'profile_id': 'routes',
#   'display_name': 'No rfc1918 routes',
#   'two_factor': False}]

# %%
response = oauth.post(api_base_uri + '/create_keypair')
keypair = response.json()['create_keypair']['data']
private_key = keypair['private_key']
certificate = keypair['certificate']
common_name = common_name_from_cert(certificate.encode('ascii'))

# %% [markdown]
# # profile config

# %%
profile_id = 'internet'
response = oauth.get(api_base_uri + f'/profile_config?profile_id={profile_id}')
config = response.text

# %% [markdown]
# # check_certificate

# %%
response = oauth.get(api_base_uri + f'/check_certificate?common_name={common_name}')
assert(response.json()['check_certificate']['data']['is_valid'])

# %% [markdown]
# # system_messages

# %%
response = oauth.get(api_base_uri + '/system_messages')

# %%
response.json()['system_messages']['data']
# Out:
# [{'type': 'notification',
#   'date_time': '2019-05-16T07:59:48Z',
#   'message': 'Welcome to the eduVPN demo server by SURFnet. If you have any questions, please let us know by mailing us on eduvpn@surfnet.nl.'}]

# %% [markdown]
# # write networkmanager config

# %%
tmp = tempfile.NamedTemporaryFile(mode='w+t')
tmp.writelines(config)
tmp.seek(0)
filename = tmp.name

# %%
connection = None
for vpn_info in NM.VpnPluginInfo.list_load():
    print("TRY:  plugin %s" % (vpn_info.get_filename()))
    try:
        vpn_plugin = vpn_info.load_editor_plugin()
    except Exception as e:
        print("SKIP: cannot load plugin: %s" % (e))
        continue
    try:
        connection = vpn_plugin.import_(filename)
    except Exception as e:
        print("SKIP: failure to import %s" % (e))
        continue
    break

if connection is None:
    print("None of the VPN plugins was able to import \"%s\"" % (filename))
    sys.exit(1)
# Out:
# TRY:  plugin /usr/lib/NetworkManager/VPN/nm-openvpn-service.name

# %%
connection.normalize()

print("connection imported from \"%s\" using plugin \"%s\" (\"%s\", %s)" % (filename, vpn_info.get_filename(), connection.get_id(), connection.get_uuid()))

client = NM.Client.new(None)

main_loop = GLib.MainLoop()

def added_cb(client, result, data):
    try:
        client.add_connection_finish(result)
        print("The connection profile has been successfully added to NetworkManager.")
    except Exception as e:
        print("ERROR: failed to add connection: %s\n" % e)
    main_loop.quit()

client.add_connection_async(connection, True, None, added_cb, None)

main_loop.run()
# Out:
# connection imported from "/tmp/tmpcwd9cq6s" using plugin "/usr/lib/NetworkManager/VPN/nm-openvpn-service.name" ("tmpcwd9cq6s", 7713a7d5-fd15-4a1c-9251-a93663ba810f)
# The connection profile has been successfully added to NetworkManager.
